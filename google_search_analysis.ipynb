# %% [markdown]
# <a href="https://colab.research.google.com/github/aaradhyabansal/redesigned-octo-lamp/blob/main/google_search_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install pytrends
import pandas as pd
import matplotlib.pyplot as plt
from pytrends.request import TrendReq
trends=TrendReq()
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
trends.build_payload(kw_list=["artificial intelligence"])
data=trends.interest_by_region()
data=data.sort_values(by=["artificial intelligence"],ascending=False)
print(data)
datai=data.head(15)
print(datai)
# Out:
#                           artificial intelligence
# geoName
# Ethiopia                                      100
# Zimbabwe                                       68
# Pakistan                                       50
# China                                          47
# India                                          43
# ...                                           ...
# Guyana                                          0
# Haiti                                           0
# Heard & McDonald Islands                        0
# Honduras                                        0
# Åland Islands                                   0
#
# [250 rows x 1 columns]
#                       artificial intelligence
# geoName
# Ethiopia                                  100
# Zimbabwe                                   68
# Pakistan                                   50
# China                                      47
# India                                      43
# ...

# %%
datai.reset_index().plot(x="geoName",
                        y="artificial intelligence",
                        figsize=(10,8),kind="bar")
plt.style.use("fivethirtyeight")
plt.show()

# %%
datai=TrendReq(hl="en-US",tz=360)
datai.build_payload(kw_list=["artificial intelligence"])
datai=trends.interest_over_time()
fig,ax=plt.subplots(figsize=(20,15))
datai["artificial intelligence"].plot()
plt.style.use("fivethirtyeight")
plt.title("Total Google Searches for artificial intelligence",font="bold")
plt.xlabel("year")
plt.ylabel("total count")
plt.show()
